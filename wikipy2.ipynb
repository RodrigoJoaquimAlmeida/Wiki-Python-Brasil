# %% [markdown]
# Faça um Programa que peça dois números e imprima o maior deles.

# %%
n1 = int(input('Digite numero: '))
n2 = int(input('Digite outro numero: '))

if n1 > n2:
    print('numero {} e maior'.format(n1))
else:
    print('numero {} e maior'.format(n2))

# %% [markdown]
# Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
numero = int(input('Digite um valor: '))

if numero >= 0:
    print('Numero e positivo')
else:
    print('Numero e negativo')
# Out:
# Digite um valor: 1
# Numero e positivo

# %% [markdown]
# Faça um Programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

# %%
palavra = input('Digite o sexo: F ou M: ')

if 'F' in palavra:
    print('Sexo feminino')
elif 'M' in palavra:
    print('Sexo masculino')
else:
    print('Sexo invalido')
# Out:
# Digite o sexo: F ou M: F
# Sexo feminino

# %% [markdown]
# Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
letra = input('Digite uma letra: ')

if letra in ('aeiou') or letra in ('AEIOU'):
    print('Voce digitou uma vogal')
elif letra.isnumeric():
    print('Voce digitou um numero')
else:
    print('Voce digitou uma consoante')
# Out:
# Digite uma letra: 1
# Voce digitou um numero

# %% [markdown]
# Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:<br>
# A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;<br>
# A mensagem "Reprovado", se a média for menor do que sete;<br>
# A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
n1 = float(input('Digite nota 1: '))
n2 = float(input('Digite nota 2: '))

media = (n1 + n2) / 2

if media >= 7:
    if media == 10:
        print('Aprovado com distinção')
    else:
        print('Aprovado')
else:
    print('Reprovado')

# %% [markdown]
# Faça um Programa que leia três números e mostre o maior deles.

# %%
n1 = int(input('Digite numero 1: '))
n2 = int(input('Digite numero 2: '))
n3 = int(input('Digite numero 3: '))


if n1 > n2 and n1 > n3:
    print('Numero 1 e maior')
elif n2 > n1 and n2 > n3:
    print('Numero 2 e maior')
else:
    if n3 > n1 and n3 > n2:
        print('Numero 3 e maior')
    else:
        print('Numeros iguais')
# Out:
# Digite numero 1: 1
# Digite numero 2: 1
# Digite numero 3: 1
# Numeros iguais

# %% [markdown]
# Faça um Programa que leia três números e mostre o maior e o menor deles.

# %%
n1 = int(input('Digite numero 1: '))
n2 = int(input('Digite numero 2: '))
n3 = int(input('Digite numero 3: '))

if n1 > n2 and n1 > n3:
    if n2 > n3:
        print('Numero 1 e maior')
        print('Numero 3 e menor')
    else:
        print('Numero 1 e maior')
        print('Numero 2 e menor')
elif n2 > n1 and n2 > n3:
    if n1 > n3:
        print('Numero 2 e maior')
        print('Numero 3 e menor')
    else:
        print('Numero 2 e maior')
        print('Numero 1 e menor')
else:
    if n3 > n1 and n3 > n2:
        if n1 > n2:
            print('Numero 3 e maior')
            print('Numero 2 e menor')
        else:
            print('Numero 3 e maior')
            print('Numero 1 e menor')
    else:
        print('Numeros iguais')
# Out:
# Digite numero 1: 1
# Digite numero 2: 1
# Digite numero 3: 1
# Numeros iguais

# %% [markdown]
# Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
n1 = int(input('Digite preco 1: '))
n2 = int(input('Digite preco 2: '))
n3 = int(input('Digite preco 3: '))

if n1 < n2 and n1 < n3:
    print('Compre o produdo 1')
elif n2 < n1 and n2 < n3:
    print('Compre o produdo 2')
else:
    if n3 < n1 and n3 < n2:
        print('Compre o produdo 3')
    else:
        print('Compre qualquer 1')
# Out:
# Digite preco 1: 1
# Digite preco 2: 1
# Digite preco 3: 1
# Compre qualquer 1

# %% [markdown]
# Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
n1 = int(input('Digite numero 1: '))
n2 = int(input('Digite numero 2: '))
n3 = int(input('Digite numero 3: '))

if n1 > n2 and n1 > n3:
    print(n1)
    if n2 > n3:
        print(n2)
        print(n3)
    else:
        print(n3)
        print(n2)
elif n2 > n1 and n2 > n3:
    print(n2)
    if n1 > n3:
        print(n1)
        print(n3)
    else:
        print(n3)
        print(n1)
else:
    if n3 > n1 and n3 > n2:
        print(n3)
        if n1 > n2:
            print(n1)
            print(n2)
        else:
            print(n2)
            print(n1)
    else:
        print('Numeros iguais')
# Out:
# Digite numero 1: 1
# Digite numero 2: 1
# Digite numero 3: 1
# Numeros iguais

# %% [markdown]
# Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno. Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
palavra = input('Qual turno voce estuda? ')

if 'M' in palavra:
    print('Bom dia!')
elif 'V' in palavra:
    print('Boa Tarde!')
elif 'N' in palavra:
    print('Boa noite!')
else:
    print('Valor invalido')
# Out:
# Qual turno voce estuda? matutino
# Valor invalido

# %% [markdown]
# As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.<br>
# Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:<br>
# salários até  280,00 (incluindo) : aumento de 20%<br>
# salários entre  280,00 e  700,00 : aumento de 15%<br>
# salários entre  700,00 e  1500,00 : aumento de 10%<br>
# salários de  1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:<br>
# o salário antes do reajuste;<br>
# o percentual de aumento aplicado;<br>
# o valor do aumento;<br>
# o novo salário, após o aumento.

# %%
salario = float(input('Digite o salario do colaborador: '))

r1 = 0.20
r2 = 0.15
r3 = 0.1
r4 = 0.05

if salario <= 280:
    salario_r1 = salario * 1.2
    salario_novo1 = salario * r1
    print('O salario antes do reajuste era', salario)
    print('O percentual de reajuste foi de', r1)
    print('O valor do aumento foi de', salario_novo1)
    print('O novo salario e de', salario_r1)
elif salario > 280 and salario <= 700:
    salario_r1 = salario * 1.15
    salario_novo1 = salario * r2
    print('O salario antes do reajuste era', salario)
    print('O percentual de reajuste foi de', r2)
    print('O valor do aumento foi de', salario_novo1)
    print('O novo salario e de', salario_r1)
elif salario > 700 and salario <= 1500:
    salario_r1 = salario * 1.1
    salario_novo1 = salario * r3
    print('O salario antes do reajuste era', salario)
    print('O percentual de reajuste foi de', r3)
    print('O valor do aumento foi de', salario_novo1)
    print('O novo salario e de', salario_r1)
else:
    salario_r1 = salario * 1.05
    salario_novo1 = salario * r4
    print('O salario antes do reajuste era', salario)
    print('O percentual de reajuste foi de', r4)
    print('O valor do aumento foi de', salario_novo1)
    print('O novo salario e de', salario_r1)
# Out:
# Digite o salario do colaborador: 100
# O salario antes do reajuste era 100.0
# O percentual de reajuste foi de 0.2
# O valor do aumento foi de 20.0
# O novo salario e de 120.0

# %% [markdown]
# Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.<br>
# Desconto do IR:<br>
# Salário Bruto até 900 (inclusive) - isento<br>
# Salário Bruto até 1500 (inclusive) - desconto de 5%<br>
# Salário Bruto até 2500 (inclusive) - desconto de 10%<br>
# Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220.<br>
#         Salário Bruto: (5 * 220)        :  1100,00<br>
#         (-) IR (5%)                     :    55,00<br>
#         (-) INSS ( 10%)                 :   110,00<br>
#         FGTS (11%)                      :   121,00<br>
#         Total de descontos              :   165,00<br>
#         Salário Liquido                 :   935,00

# %%
valor_hora = input('Digite o valor/hora: ')
hora_trab = input("Digite o total de horas no mes: ")

sind = 0.03
fgts = 0.11
inss = 0.1
ir0 = 0
ir1 = 0.05
ir2 = 0.1
ir3 = 0.2

if valor_hora.isnumeric() and hora_trab.isnumeric():
    valor_hora = int(valor_hora)
    hora_trab = int(hora_trab)
    salario_bruto = valor_hora * hora_trab
    if salario_bruto <=900:
        descontos = (salario_bruto * sind) + (salario_bruto * inss) + (salario_bruto * ir0)
        salario_liq = salario_bruto - descontos
        print('Salario Bruto {} * {} e de {}'.format(valor_hora, hora_trab, salario_bruto))
        print('Sindicato e {}'.format(salario_bruto * sind))
        print('IR e de {}'.format(salario_bruto * ir0))
        print('INSS e de {}'.format(salario_bruto * inss))
        print('FGTS e de {}'.format(salario_bruto * fgts))
        print('Total de descontos: {}'.format(descontos))
        print('Salario Liquido: {}'.format(salario_liq))
    elif salario_bruto <= 1500:
        descontos = (salario_bruto * sind) + (salario_bruto * inss) + (salario_bruto * ir1)
        salario_liq = salario_bruto - descontos
        print('Salario Bruto {} * {} e de {}'.format(valor_hora, hora_trab, salario_bruto))
        print('Sindicato e {}'.format(salario_bruto * sind))
        print('IR e de {}'.format(salario_bruto * ir1))
        print('INSS e de {}'.format(salario_bruto * inss))
        print('FGTS e de {}'.format(salario_bruto * fgts))
        print('Total de descontos: {}'.format(descontos))
        print('Salario Liquido: {}'.format(salario_liq))
    elif salario_bruto <= 2500:
        descontos = (salario_bruto * sind) + (salario_bruto * inss) + (salario_bruto * ir2)
        salario_liq = salario_bruto - descontos
        print('Salario Bruto {} * {} e de {}'.format(valor_hora, hora_trab, salario_bruto))
        print('Sindicato e {}'.format(salario_bruto * sind))
        print('IR e de {}'.format(salario_bruto * ir2))
        print('INSS e de {}'.format(salario_bruto * inss))
        print('FGTS e de {}'.format(salario_bruto * fgts))
        print('Total de descontos: {}'.format(descontos))
        print('Salario Liquido: {}'.format(salario_liq))
    else:
        descontos = (salario_bruto * sind) + (salario_bruto * inss) + (salario_bruto * ir3)
        salario_liq = salario_bruto - descontos
        print('Salario Bruto {} * {} e de {}'.format(valor_hora, hora_trab, salario_bruto))
        print('Sindicato e {}'.format(salario_bruto * sind))
        print('IR e de {}'.format(salario_bruto * ir3))
        print('INSS e de {}'.format(salario_bruto * inss))
        print('FGTS e de {}'.format(salario_bruto * fgts))
        print('Total de descontos: {}'.format(descontos))
        print('Salario Liquido: {}'.format(salario_liq))
else:
    print('Valor invalido')
# Out:
# Digite o valor/hora: 1
# Digite o total de horas no mes: 2
# Salario Bruto 1 * 2 e de 2
# Sindicato e 0.06
# IR e de 0
# INSS e de 0.2
# FGTS e de 0.22
# Total de descontos: 0.26
# Salario Liquido: 1.74

# %% [markdown]
# Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

# %%
dia = input('Digite um numero de 1 a 7: ' )
semana = ['domingo', 'segunda', 'terça', 'quarta', 'quinta', 'sexta', 'sabado']

if dia.isnumeric():
    dia = int(dia)
    if dia > 0 and dia < 8:
        if dia == 1:
            print(semana[0])
        elif dia == 2:
            print(semana[1])
        elif dia == 3:
            print(semana[2])
        elif dia == 4:
            print(semana[3])
        elif dia == 5:
            print(semana[4])
        elif dia == 6:
            print(semana[5])
        else:
            print(semana[6])
    else:
        print('Valor invalido')
else:
    print('Valor Invalido')
# Out:
# Digite um numero de 1 a 7: 1
# domingo

# %% [markdown]
# Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. A atribuição de conceitos obedece à tabela abaixo:<br>
#   Média de Aproveitamento  Conceito<br>
#   Entre 9.0 e 10.0        A<br>
#   Entre 7.5 e 9.0         B<br>
#   Entre 6.0 e 7.5         C<br>
#   Entre 4.0 e 6.0         D<br>
#   Entre 4.0 e zero        E<br>
#
# O algoritmo deve mostrar na tela as notas, a média, o conceito correspondente e a mensagem “APROVADO” se o conceito for A, B ou C ou “REPROVADO” se o conceito for D ou E.

# %%
n1 = input('Digite a nota N1: ')
n2 = input('Digite a nota N2: ')
nota_letra = ['A', 'B', 'C', 'D', 'E']

if n1 and n2:
    n1 = float(n1)
    n2 = float(n2)
    media = (n1 + n2) / 2
    if media >= 0 and media <= 10:
        if media <= 4:
            print(' N1: {}\n N2: {}\n Media Aluno: {}\n Aproveitamento {}\n REPROVADO'.format(n1, n2, media, nota_letra[4]))
        elif media > 4 and media <= 6:
            print(' N1: {}\n N2: {}\n Media Aluno: {}\n Aproveitamento {}\n REPROVADO'.format(n1, n2, media, nota_letra[3]))
        elif media > 6 and media <= 7.5:
            print(' N1: {}\n N2: {}\n Media Aluno: {}\n Aproveitamento {}\n APROVADO'.format(n1, n2, media, nota_letra[2]))
        elif media > 7.5 and media <= 9:
            print(' N1: {}\n N2: {}\n Media Aluno: {}\n Aproveitamento {}\n APROVADO'.format(n1, n2, media, nota_letra[1]))
        else:
            print(' N1: {}\n N2: {}\n Media Aluno: {}\n Aproveitamento {}\n APROVADO'.format(n1, n2, media, nota_letra[0]))       
    else:
        print('Valores invalidos')
else:
    print('Valores invalidos')
# Out:
# Digite a nota N1: 6
# Digite a nota N2: 6.3
#  N1: 6.0
#  N2: 6.3
#  Media Aluno: 6.15
#  Aproveitamento C
#  APROVADO

# %% [markdown]
# Faça um Programa que peça os 3 lados de um triângulo. O programa deverá informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo, se o mesmo é: equilátero, isósceles ou escaleno.<br>
# Dicas:<br>
# Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;<br>
# Triângulo Equilátero: três lados iguais;<br>
# Triângulo Isósceles: quaisquer dois lados iguais;<br>
# Triângulo Escaleno: três lados diferentes;

# %%
lado1 = input('Digite lado 1 do triangulo: ')
lado2 = input('Digite lado 2 do triangulo: ')
lado3 = input('Digite lado 3 do triangulo: ')

if lado1 and lado2 and lado3:
    lado1 = float(lado1)
    lado2 = float(lado2)
    lado3 = float(lado3)
    
    if (lado1 + lado2) > lado3 or (lado1 + lado3) > lado2 or (lado2 + lado3) > lado1:
        print('Valores podem ser um triangulo')
        if lado1 == lado2 and lado1 == lado3:
            print('Triangulo equilatero')
        elif lado1 == lado2 or lado1 == lado3:
            print('Trinagulo isosceles')
        else:
            print('Trinagulo escaleno')
# Out:
# Digite lado 1 do triangulo: 1
# Digite lado 2 do triangulo: 1
# Digite lado 3 do triangulo: 1
# Valores podem ser um triangulo
# Triangulo equilatero

# %% [markdown]
# Faça um programa que calcule as raízes de uma equação do segundo grau, na forma ax2 + bx + c. O programa deverá pedir os valores de a, b e c e fazer as consistências, informando ao usuário nas seguintes situações:<br>
# Se o usuário informar o valor de A igual a zero, a equação não é do segundo grau e o programa não deve fazer pedir os demais valores, sendo encerrado;<br>
# Se o delta calculado for negativo, a equação não possui raizes reais. Informe ao usuário e encerre o programa;<br>
# Se o delta calculado for igual a zero a equação possui apenas uma raiz real; informe-a ao usuário;<br>
# Se o delta for positivo, a equação possui duas raiz reais; informe-as ao usuário;

# %%
valor_a = input('Digite o valor de a: ')
if '0' in valor_a:
    print('Equação nao e do segundo grau. Programa encerrado')
    
else:
    valor_b = input('Digite o valor de b: ')
    valor_c = input('Digite o valor de c: ')

    if valor_b and valor_c:
        valor_a = float(valor_a)
        valor_b = float(valor_b)
        valor_c = float(valor_c)
        delta = (valor_a * (1 * 1)) + (valor_b * 1) + valor_c

        if delta < 0:
            print('Equação na possui raizes reais. Programa terminado')
        elif delta == 0:
            print('Equação possui apenas uma raiz real.')
        else:
            print('Equação possui duas raizes reais')
# Out:
# Digite o valor de a: 0
# Equação nao e do segundo grau. Programa encerrado

# %% [markdown]
# Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.

# %%
ano = int(input('Digite o ano: '))

if ano % 4 == 0:
    if ano % 100 != 0:
        print('Ano Bissexto')
    else:
        print('Ano Nao Bissexto')
elif ano % 400 == 0:
    print('Ano Bissexto')
else:
    print('Ano Nao Bissexto')
# Out:
# Digite o ano: 2022
# Ano Nao Bissexto

# %% [markdown]
# Faça um Programa que peça uma data no formato dd/mm/aaaa e determine se a mesma é uma data válida.

# %%
data = input('Digite a data no formato dd/mm/aaaa: ')

data2 = data.split('/')

int_data = list(map(int, data2))

if int_data[0] > 31 or int_data[1] > 12:
    print('Data invalida')
else:
    print('A data {} é valida'.format(data))
# Out:
# Digite a data no formato dd/mm/aaaa: 01/01/2021
# A data 01/01/2021 é valida

# %% [markdown]
# Faça um Programa que leia um número inteiro menor que 1000 e imprima a quantidade de centenas, dezenas e unidades do mesmo.
# Observando os termos no plural a colocação do "e", da vírgula entre outros. Exemplo:<br>
# 326 = 3 centenas, 2 dezenas e 6 unidades<br>
# 12 = 1 dezena e 2 unidades Testar com: 326, 300, 100, 320, 310,305, 301, 101, 311, 111, 25, 20, 10, 21, 11, 1, 7 e 16

# %%
numero = int(input('Digite um numero menor que 1000: '))

if numero < 1000:
    centenas = numero / 100
    dezenas = numero % 100
    dezenas /= 10
    unidades = numero % 10
    if numero > 100:
        print('{} = {} centenas, {} dezenas e {} unidades'.format(numero, int(centenas), int(dezenas), unidades))
    elif numero >= 10 and numero < 100:
        print('{} = {} dezenas e {} unidades'.format(numero, int(dezenas), unidades))
    else:
        print('{} = {} unidades'.format(numero, unidades))
# Out:
# Digite um numero menor que 1000: 1
# 1 = 1 unidades

# %% [markdown]
# Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:<br>
# A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;<br>
# A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;<br>
# A mensagem "Aprovado com Distinção", se a média for igual a 10.

# %%
n1 = float(input('Digite nota 1: '))
n2 = float(input('Digite nota 2: '))
n3 = float(input('Digite nota 3: '))

media = (n1 + n2 + n3) / 3

if media >= 7:
    if media == 10:
        print('Aprovado com distinção com nota {}'.format(media))
    else:
        print('Aprovado com media {}'.format(media))
else:
    print('Reprovado com media {}'.format(media))
# Out:
# Digite nota 1: 1
# Digite nota 2: 1
# Digite nota 3: 1
# Reprovado com media 1.0

# %% [markdown]
# Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois informar quantas notas de cada valor serão fornecidas. As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.<br>
# Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;<br>
# Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.

# %%
saque = int(input("Digite o valor do saque. Autorizado valores entre 10 e 600 reais: "))

n100 = saque % 100
n50 = saque % 50
n10 = saque % 10

if saque >= 100 and saque <= 600:
    saque100 = saque // 100
    if  n100 >=50:
        saque50 = n100 // 50
        sobra50 = n100 - 50
        if sobra50 >= 10:
            saque10 = sobra50 // 10
            sobra10 = sobra50 % 10
            if sobra10 >= 5:
                saque5 = sobra10 // 5
                sobra1 = sobra10 - 5
                if sobra1 >= 1:
                    print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50, {} notas de 10, {} nota de 5 e {} notas de 1'.format(saque, saque100, saque50, saque10, saque5, sobra1))
                else:
                    print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50, {} notas de 10 e {} nota de 5'.format(saque, saque100, saque50, saque10, saque5))
            else:
                print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50 e {} notas de 10'.format(saque, saque100, saque50, saque10))
        elif sobra50 >=5:
            saque5 = sobra50 // 5
            sobra1 = sobra50 - 5
            if sobra1 >= 1:
                print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50, {} nota de 5 e {} notas de 1'.format(saque, saque100, saque50, saque5, sobra1))
            else:
                print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50, {} nota de 5'.format(saque, saque100, saque50, saque5))
        elif sobra50 >=1:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50, {} nota de 1'.format(saque, saque100, saque50, sobra50))
        else:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 50'.format(saque, saque100, saque50))
    elif n100 >= 10 and n100 < 50:
        saque10 = n100 // 10
        sobra10 = n100 % 10
        if sobra10 >= 5:
            saque5 = sobra10 // 5
            sobra1 = sobra10 - 5
            if sobra1 >= 1:
                print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} notas de 10, {} nota de 5 e {} notas de 1'.format(saque, saque100, saque10, saque5, sobra1))
            else:
                print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} notas de 10 e {} nota de 5'.format(saque, saque100, saque10, saque5))
        else:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100 e {} notas de 10'.format(saque, saque100, saque10))
    elif n100 >=5 and n100 < 10: 
        saque5 = n100 // 5
        sobra1 = n100 - 5
        if sobra1 >= 1:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100, {} nota de 5 e {} notas de 1'.format(saque, saque100, saque5, sobra1))
        else:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100 e {} nota de 5'.format(saque, saque100, saque5))
    elif n100 >=1 and n100 < 5:
        print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100 e {} notas de 1'.format(saque, saque100, n100))
    else:
        print('Para sacar a quantia de {} reais, o programa fornece {} notas de 100'.format(saque, saque100))
        
elif saque >= 50 and saque < 100 :
    saque50 = saque // 50
    if n50 >= 10:
        saque10 = n50 // 10
        sobra10 = n50 % 10
        if sobra10 >= 5:
            saque5 = sobra10 // 5
            sobra1 = sobra10 - 5
            if sobra1 >= 1:
                print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50, {} notas de 10, {} nota de 5 e {} notas de 1'.format(saque, saque50, saque10, saque5, sobra1))
            else:
                print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50, {} notas de 10 e {} nota de 5'.format(saque, saque50, saque10, saque5))
        else:
            print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50 e {} notas de 10'.format(saque, saque50, saque10))
    elif n50 >= 5:
        saque5 = n50 // 5
        sobra1 = n50 - 5
        if sobra1 >= 1:
            print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50, {} nota de 5 e {} notas de 1'.format(saque, saque50, saque5, sobra1))
        else:
            print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50 e {} nota de 5'.format(saque, saque50, saque5))
    elif n50 >= 1:
        print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50 e {} notas de 1'.format(saque, saque50, sobra1))
    else:
        print('Para sacar a quantia de {} reais, o programa fornece {} nota de 50'.format(saque, saque50))
elif saque >= 10 and saque < 50:
    saque10 = saque // 10
    if n10 >= 5:
        saque5 = n10 // 5
        sobra1 = n10 - 5
        if sobra1 >= 1 and sobra1 < 5:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 10, {} nota de 5 e {} notas de 1'.format(saque, saque10, saque5, sobra1))
        else:
            print('Para sacar a quantia de {} reais, o programa fornece {} notas de 10 e {} nota de 5'.format(saque, saque10, saque5))
    elif n10 >= 1 and n10 < 5:
        print('Para sacar a quantia de {} reais, o programa fornece {} notas de 10 e {} notas de 1'.format(saque, saque10, n10))
    else:
        print('Para sacar a quantia de {} reais, o programa fornece {} notas de 10'.format(saque, saque10))
else:
    print('Valor de saque incorreto')
# Out:
# Digite o valor do saque. Autorizado valores entre 10 e 600 reais: 399
# Para sacar a quantia de 399 reais, o programa fornece 3 notas de 100, 1 nota de 50, 4 notas de 10, 1 nota de 5 e 4 notas de 1

# %%
fatoreal = 66 % 50

print(fatoreal)
# Out:
# 16
